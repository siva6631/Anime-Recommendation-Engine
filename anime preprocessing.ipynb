# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r'C:\Users\sivas\OneDrive\Documents\Animedata.xlsx')

df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                          GintamaÂ°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
df.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
#episodes column dtype is wrong

# %%
df['name'].value_counts()
# Out:
# name
# 1                                                 2
# Saru Kani Gassen                                  2
# Shi Wan Ge Leng Xiaohua                           2
# Kimi no Na wa.                                    1
# Bakabon Osomatsu no Karee wo Tazunete Sansenri    1
#                                                  ..
# Yoroiden Samurai Troopers Kikoutei Densetsu       1
# Yuuâ˜†Yuuâ˜†Hakusho: Mu Mu Hakusho                1
# 3-gatsu no Lion meets Bump of Chicken             1
# Bannou Bunka Neko-Musume                          1
# Yasuji no Pornorama: Yacchimae!!                  1
# Name: count, Length: 12291, dtype: int64

# %%
df['name'].nunique()
# Out:
# 12291

# %%
df['genre'].value_counts()
# Out:
# genre
# Hentai                                                  823
# Comedy                                                  523
# Music                                                   301
# Kids                                                    199
# Comedy, Slice of Life                                   179
#                                                        ...
# Adventure, Drama, Fantasy, Game, Sci-Fi                   1
# Adventure, Demons, Fantasy, Historical                    1
# Action, Comedy, Drama, Mecha, Music, Sci-Fi, Shounen      1
# Action, Comedy, Fantasy, Mecha, Sci-Fi, Shounen           1
# Hentai, Slice of Life                                     1
# Name: count, Length: 3264, dtype: int64

# %%
df['genre'].nunique()
# Out:
# 3264

# %%
df['type'].value_counts()
# Out:
# type
# TV         3787
# OVA        3311
# Movie      2348
# Special    1676
# ONA         659
# Music       488
# Name: count, dtype: int64

# %%
df['episodes'].nunique()
# Out:
# 187

# %%
df['rating'].value_counts()
# Out:
# rating
# 6.00    141
# 7.00     99
# 6.50     90
# 6.25     84
# 5.00     76
#        ...
# 3.47      1
# 3.71      1
# 3.87      1
# 3.91      1
# 3.14      1
# Name: count, Length: 598, dtype: int64

# %%
df['rating'].nunique()
# Out:
# 598

# %%
df['members'].nunique()
# Out:
# 6706

# %%
df['name'].tolist()
# Out:
# ['Kimi no Na wa.',
#  'Fullmetal Alchemist: Brotherhood',
#  'GintamaÂ°',
#  'Steins;Gate',
#  'Gintama&#039;',
#  'Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou',
#  'Hunter x Hunter (2011)',
#  'Ginga Eiyuu Densetsu',
#  'Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare',
#  'Gintama&#039;: Enchousen',
#  'Clannad: After Story',
#  'Koe no Katachi',
#  'Gintama',
#  'Code Geass: Hangyaku no Lelouch R2',
#  'Haikyuu!! Second Season',
#  'Sen to Chihiro no Kamikakushi',
#  'Shigatsu wa Kimi no Uso',
#  'Mushishi Zoku Shou 2nd Season',
#  'Ookami Kodomo no Ame to Yuki',
#  'Code Geass: Hangyaku no Lelouch',
#  'Hajime no Ippo',
#  'Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen',
#  'Cowboy Bebop',
#  'One Punch Man',
#  'Mononoke Hime',
#  'Suzumiya Haruhi no Shoushitsu',
#  'Monogatari Series: Second Season',
#  'Mushishi Zoku Shou',
#  'Mushishi',
#  'Tengen Toppa Gurren Lagann',
#  'Great Teacher Onizuka',
#  'Natsume Yuujinchou Go',
# ...

# %%
df['genre'].tolist()
# Out:
# ['Drama, Romance, School, Supernatural',
#  'Action, Adventure, Drama, Fantasy, Magic, Military, Shounen',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Sci-Fi, Thriller',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Comedy, Drama, School, Shounen, Sports',
#  'Action, Adventure, Shounen, Super Power',
#  'Drama, Military, Sci-Fi, Space',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Drama, Fantasy, Romance, Slice of Life, Supernatural',
#  'Drama, School, Shounen',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Action, Drama, Mecha, Military, Sci-Fi, Super Power',
#  'Comedy, Drama, School, Shounen, Sports',
#  'Adventure, Drama, Supernatural',
#  'Drama, Music, Romance, School, Shounen',
#  'Adventure, Fantasy, Historical, Mystery, Seinen, Slice of Life, Supernatural',
#  'Fantasy, Slice of Life',
# ...

# %%
df.iloc[12289,:]
# Out:
# anime_id                                            9316
# name        Toushindai My Lover: Minami tai Mecha-Minami
# genre                                             Hentai
# type                                                 OVA
# episodes                                               1
# rating                                              4.15
# members                                              211
# Name: 12289, dtype: object

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
#extracting genres and types of movie to observe  which are 18+ content movies and what streaming platform

# %%
pd.set_option('display.max_rows',None)
df[df['genre']=='Hentai']
# Out:
#        anime_id                                               name   genre  \
# 11114     11879                                Oni Chichi: Re-born  Hentai
# 11115     29575                                 Mankitsu Happening  Hentai
# 11116     15843                       Koiito Kinenbi The Animation  Hentai
# 11117     21097                                Oni Chichi: Rebuild  Hentai
# 11119     10779                Eroge! H mo Game mo Kaihatsu Zanmai  Hentai
# 11120     10380                               Oni Chichi: Re-birth  Hentai
# 11122     22069                           Swing Out Sisters (2014)  Hentai
# 11124     12375                                  Maki-chan to Nau.  Hentai
# 11125      3559          Stringendo: Angel-tachi no Private Lesson  Hentai
# 11126     32587                                      Shoujo Ramune  Hentai
# 11127     21829  Fella Pure: Mitarashi-san Chi no Jijou The Ani...  Hentai
# ...

# %%
#creating variable related on their columns dtypes wise

# %%
categorical=['name','genre','type']
continous=['rating']
count=['anime_id','episodes','members']

# %%
# statistical observation

# %%
df[categorical].describe()
# Out:
#          name   genre   type
# count   12294   12232  12269
# unique  12291    3264      6
# top         1  Hentai     TV
# freq        2     823   3787

# %%
df[continous].describe()
# Out:
#              rating
# count  12064.000000
# mean       6.473902
# std        1.026746
# min        1.670000
# 25%        5.880000
# 50%        6.570000
# 75%        7.180000
# max       10.000000

# %%
# observation on visualization

# %%
# plt.figure(figsize=(10,5),dpi=250)
sns.histplot(df[continous],kde=True)
plt.show()

# %%
# for i in categorical:
#     plt.figure(figsize=(10,15),dpi=500)
#     print(sns.countplot(df[i]))
#     plt.show()

# %%
pd.crosstab(df['genre'],df['type'])
# Out:
# type                                                Movie  Music  ONA  OVA  \
# genre
# Action                                                 18      0   13   11
# Action, Adventure                                       4      0    1    3
# Action, Adventure, Cars, Comedy, Sci-Fi, Shounen        1      0    0    1
# Action, Adventure, Cars, Mecha, Sci-Fi, Shounen...      0      0    0    0
# Action, Adventure, Cars, Sci-Fi                         1      0    0    0
# Action, Adventure, Comedy                               4      0    0    2
# Action, Adventure, Comedy, Demons, Drama, Ecchi...      0      0    0    0
# Action, Adventure, Comedy, Demons, Fantasy, Magic       0      0    0    0
# Action, Adventure, Comedy, Demons, Fantasy, Mag...      0      0    0    0
# Action, Adventure, Comedy, Demons, Fantasy, Mar...      1      0    0    0
# Action, Adventure, Comedy, Demons, Magic, Super...      0      0    0    0
# ...

# %%
# checking null values and skewness and duplicated values and outliers

# %%
df[continous].skew()
# Out:
# rating   -0.54357
# dtype: float64

# %%
df.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(df[continous])
plt.show()

# %%
#data preprocessing

# %%
#treating null values

# %%
df[df['genre'].isnull()]
# Out:
#        anime_id                                               name genre  \
# 2844      33242             ACTION, ROMANCE, SCIENCE FICTION,Harem   NaN
# 3541      33589                                      ViVid Strike!   NaN
# 6040      29765                                  Metropolis (2009)   NaN
# 6646      32695                                       Match Shoujo   NaN
# 7018      33187                                   Katsudou Shashin   NaN
# 7198      30862                               Yubi wo Nusunda Onna   NaN
# 7335      28987                                           Kamakura   NaN
# 7349      19219                                        Modern No.2   NaN
# 7426      29629                                       Coffee Break   NaN
# 7498      28653                                               Maze   NaN
# 7591      31834                                         Mormorando   NaN
# 7645      31507                              Ari Ningen Monogatari   NaN
# ...

# %%
df['genre']=df['genre'].fillna(df['genre'].mode()[0])

# %%
df[df['genre'].isnull()]
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
#extracting null value of rating column

# %%
df[df['rating'].isnull()]
# Out:
#        anime_id                                               name  \
# 8968      34502                                    Inazma Delivery
# 9657      34309  Nananin no Ayakashi: Chimi Chimi Mouryou!! Gen...
# 10896     34096                                     Gintama (2017)
# 10897     34134                                    One Punch Man 2
# 10898     30484                                      Steins;Gate 0
# 10899     25777                        Shingeki no Kyojin Season 2
# 10900     34437                    Code Geass: Fukkatsu no Lelouch
# 10901     33486                   Boku no Hero Academia 2nd Season
# 10902     32937           Kono Subarashii Sekai ni Shukufuku wo! 2
# 10903     33506                  Ao no Exorcist: Kyoto Fujouou-hen
# 10904     33417                                     Super Lovers 2
# 10905     30727                   Saenai Heroine no Sodatekata â™­
# 10906     33352                                  Violet Evergarden
# ...

# %%
df['rating']=df['rating'].fillna(df['rating'].median())

# %%
df[df['rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
#after treating null values checking outliers of rating column

# %%
sns.boxplot(df['rating'])
plt.show()

# %%
#extracting outliers

# %%
q1=df['rating'].quantile(0.25)
q1
# Out:
# 5.9

# %%
q3=df['rating'].quantile(0.75)
q3
# Out:
# 7.17

# %%
# inter quantile range

# %%
iqr=q3-q1
iqr
# Out:
# 1.2699999999999996

# %%
# upper limit and lower limit

# %%
ul=q3+(1.5*iqr)
ul
# Out:
# 9.075

# %%
ll=q1-(1.5*iqr)
ll
# Out:
# 3.995000000000001

# %%
df[(df['rating']>ul)|(df['rating']<ll)]
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                          GintamaÂ°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# 5         32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6         11061                             Hunter x Hunter (2011)
# 7           820                               Ginga Eiyuu Densetsu
# 8         15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9         15417                           Gintama&#039;: Enchousen
# 8009       1657          Byston Well Monogatari: Garzey no Tsubasa
# 8010      22181                                             Shunga
# 8011      28637                                             Dreams
# ...

# %%
# based on research and imbd site those outliers are not real those rating are real life matching 
#so retrain the outliers

# %%
#no skewness

# %%
#no duplicated values

# %%
#numerical encoding

# %%
df.to_csv('cleananimedata.csv',index=False)

# %%
cd
# Out:
# C:\Users\sivas
